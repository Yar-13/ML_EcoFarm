# %% [markdown]
# <div class="alert alert-info">
#
# <b>Привет!👋</b>
#
# Меня зовут Тарас, я буду проверять твой проект. У нас, в Яндекс практикуме, принято обращение на "ты"😏, но если тебе комфортнее обращаться на Вы, напиши об этом, пожалуйста. Я с удовольствием ерейду на "Вы".
#
# Я помогу тебе с учёбой для будущего успешного поиска работы. Вместе мы оптимизируем твой код и оптимально решим задачи!
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Будет здорово, если ты будешь отвечать на мои комментарии своими, выделяя их цветами или так, как тебе понравится, но так, чтобы их можно было отличить от моих комментариев. Это нужно, чтобы не создавалась путаница😉
#
# Ты увидишь мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Если в решении будут какие-то неточности, в первый раз я только укажу на их наличие и дам тебе возможность самостоятельно найти и исправить их. В реальной работе твои более опытные товарищи будут поступать также, и я хочу подготовить тебя именно к работе. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
# Мы все очень ценим время и усилия друг-друга, поэтому я постараюсь давать максимально эффективные комментарии и заботливо подойти к твоей работе.
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных." data-toc-modified-id="Описание-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных.</a></span></li><li><span><a href="#Первичное-ознакомление-с-данными." data-toc-modified-id="Первичное-ознакомление-с-данными.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Первичное ознакомление с данными.</a></span></li><li><span><a href="#Предобработка-данных." data-toc-modified-id="Предобработка-данных.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Предобработка данных.</a></span></li><li><span><a href="#Исследовательский-анализ-данных." data-toc-modified-id="Исследовательский-анализ-данных.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных.</a></span><ul class="toc-item"><li><span><a href="#ferma_main" data-toc-modified-id="ferma_main-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>ferma_main</a></span><ul class="toc-item"><li><span><a href="#milk_yield" data-toc-modified-id="milk_yield-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>milk_yield</a></span></li><li><span><a href="#efu" data-toc-modified-id="efu-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>efu</a></span></li><li><span><a href="#raw_protein" data-toc-modified-id="raw_protein-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>raw_protein</a></span></li><li><span><a href="#spr" data-toc-modified-id="spr-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>spr</a></span></li><li><span><a href="#fat" data-toc-modified-id="fat-5.1.5"><span class="toc-item-num">5.1.5&nbsp;&nbsp;</span>fat</a></span></li><li><span><a href="#protein" data-toc-modified-id="protein-5.1.6"><span class="toc-item-num">5.1.6&nbsp;&nbsp;</span>protein</a></span></li><li><span><a href="#breed" data-toc-modified-id="breed-5.1.7"><span class="toc-item-num">5.1.7&nbsp;&nbsp;</span>breed</a></span></li><li><span><a href="#pasture" data-toc-modified-id="pasture-5.1.8"><span class="toc-item-num">5.1.8&nbsp;&nbsp;</span>pasture</a></span></li><li><span><a href="#bull_breed" data-toc-modified-id="bull_breed-5.1.9"><span class="toc-item-num">5.1.9&nbsp;&nbsp;</span>bull_breed</a></span></li><li><span><a href="#taste_milk" data-toc-modified-id="taste_milk-5.1.10"><span class="toc-item-num">5.1.10&nbsp;&nbsp;</span>taste_milk</a></span></li><li><span><a href="#age" data-toc-modified-id="age-5.1.11"><span class="toc-item-num">5.1.11&nbsp;&nbsp;</span>age</a></span></li></ul></li><li><span><a href="#ferma_dad" data-toc-modified-id="ferma_dad-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>ferma_dad</a></span></li><li><span><a href="#cow_buy" data-toc-modified-id="cow_buy-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>cow_buy</a></span><ul class="toc-item"><li><span><a href="#fat" data-toc-modified-id="fat-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>fat</a></span></li><li><span><a href="#protein" data-toc-modified-id="protein-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>protein</a></span></li><li><span><a href="#breed" data-toc-modified-id="breed-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>breed</a></span></li><li><span><a href="#pasture" data-toc-modified-id="pasture-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>pasture</a></span></li><li><span><a href="#bull_breed" data-toc-modified-id="bull_breed-5.3.5"><span class="toc-item-num">5.3.5&nbsp;&nbsp;</span>bull_breed</a></span></li><li><span><a href="#name_bull" data-toc-modified-id="name_bull-5.3.6"><span class="toc-item-num">5.3.6&nbsp;&nbsp;</span>name_bull</a></span></li><li><span><a href="#age" data-toc-modified-id="age-5.3.7"><span class="toc-item-num">5.3.7&nbsp;&nbsp;</span>age</a></span></li></ul></li></ul></li><li><span><a href="#корреляционный-анализ-признаков-в-датасете-ferma_main.csv" data-toc-modified-id="корреляционный-анализ-признаков-в-датасете-ferma_main.csv-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>корреляционный анализ признаков в датасете <code>ferma_main.csv</code></a></span></li><li><span><a href="#Задача-регрессии." data-toc-modified-id="Задача-регрессии.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Задача регрессии.</a></span><ul class="toc-item"><li><span><a href="#первая-модель" data-toc-modified-id="первая-модель-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>первая модель</a></span></li><li><span><a href="#вторая-модель" data-toc-modified-id="вторая-модель-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>вторая модель</a></span></li><li><span><a href="#Третья-модель" data-toc-modified-id="Третья-модель-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Третья модель</a></span></li><li><span><a href="#Сравнение-качества-моделей" data-toc-modified-id="Сравнение-качества-моделей-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Сравнение качества моделей</a></span></li><li><span><a href="#Прогнозирование-лучшей-модели" data-toc-modified-id="Прогнозирование-лучшей-модели-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Прогнозирование лучшей модели</a></span></li></ul></li><li><span><a href="#Задача-классификации." data-toc-modified-id="Задача-классификации.-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Задача классификации.</a></span><ul class="toc-item"><li><span><a href="#Подбор-порога-классификации." data-toc-modified-id="Подбор-порога-классификации.-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Подбор порога классификации.</a></span></li><li><span><a href="#Целевое-предсказание" data-toc-modified-id="Целевое-предсказание-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Целевое предсказание</a></span></li></ul></li><li><span><a href="#Итоговые-выводы" data-toc-modified-id="Итоговые-выводы-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Итоговые выводы</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Вы работаете в IT-компании, которая выполняет на заказ проекты по машинному обучению. К вам обратился фермер, владелец молочного хозяйства «Вольный луг». Он хочет купить бурёнок, чтобы расширить поголовье стада коров. Для этого он заключил выгодный контракт с ассоциацией пастбищ «ЭкоФерма».
#
# Условия позволяют фермеру очень тщательно отобрать коров. Он определяет качество молока по строгой методике, и при этом ему нужно выполнять свой план развития молочного хозяйства. Фермер хочет, чтобы каждая бурёнка давала не менее 6000 килограммов молока в год, а её надой был вкусным — строго по его критериям, ничуть не хуже. А продавцы и технологи так и норовят приукрасить своих коровок!
#
# Поэтому он просит вас разработать модель машинного обучения, которая поможет ему управлять рисками и принимать объективное решение о покупке. «ЭкоФерма» готова предоставить подробные данные о своих коровах. Вам нужно создать две прогнозные модели для отбора бурёнок в поголовье:
# - Первая будет прогнозировать возможный удой коровы (целевой признак Удой);
# - Вторая — рассчитывать вероятность получить вкусное молоко от коровы (целевой признак Вкус молока).

# %% [markdown]
# ## Описание данных.

# %% [markdown]
# Имеется три датасета: `ferma_main.csv`, `ferma_dad.csv`, `cow_buy.csv`.
#
# Файл `ferma_main.csv` содержит данные о стаде фермера на текущий момент.
#
# - id - уникальный идентификатор коровы.
# - Удой, кг - масса молока, которую корова даёт в год (в килограммах).
# - ЭКЕ (Энергетическая кормовая единица) - показатель питательности корма коровы.
# - Сырой протеин, г - содержание сырого протеина в корме (в граммах).
# - СПО (Сахаро-протеиновое соотношение) - отношение сахара к протеину в корме коровы.
# - Порода - порода коровы
# - Тип пастбища - ландшафт лугов, на которых паслась корова.
# - порода папы_быка - порода папы коровы.
# - Жирность,% - содержание жиров в молоке (в процентах).
# - Белок,% - содержание белков в молоке (в процентах).
# - Вкус молока - оценка вкуса по личным критериям фермера, бинарный признак (вкусно, не вкусно).
# - Возраст - возраст коровы, бинарный признак (менее_2_лет, более_2_лет).
#
# Файл `ferma_dad.csv` хранит имя папы каждой коровы в стаде фермера.
#
# - id - уникальный идентификатор коровы.
# - Имя Папы -  имя папы коровы.
#
# Файл `cow_buy.csv` — это данные о коровах «ЭкоФермы», которых фермер хочет изучить перед покупкой.
#
# - Порода - порода коровы.
# - Тип пастбища - ландшафт лугов, на которых паслась корова.
# - порода папы_быка - порода папы коровы.
# - Имя_папы - имя папы коровы.
# - Текущая_жирность,% - содержание жиров в молоке (в процентах).
# - Текущий_уровень_белок,% - содержание белков в молоке (в процентах).
# - Возраст - возраст коровы, бинарный признак (менее_2_лет, более_2_лет).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что подробно расписываешь описание проекта, план и описание данных!
#
# Отличное оформление, сразу виден серьёзный подход🤓.

# %% [markdown]
# ## Первичное ознакомление с данными.

# %%
# убрать предупреждения
import warnings
warnings.filterwarnings('ignore')

# %%
# импорт необходимых библиотек.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score, recall_score, precision_score, confusion_matrix

# %%
# настроим точность вывода до 2-х десятичных знаков и разделители тысяч (групп разрядов) для больших чисел
pd.set_option('display.float_format', '{:,.2f}'.format)

# необходимо для показа всех столбцов.
pd.options.display.max_columns = None 

# установим графическую тему для графиков и гистограмм
plt.style.use('seaborn')

# %%
# загрузка датафреймов.

try:
    df_fm = pd.read_csv('/datasets/ferma_main.csv', sep=';')
    df_fd = pd.read_csv('/datasets/ferma_dad.csv', sep=';')
    df_cb = pd.read_csv('/datasets/cow_buy.csv', sep=';')
    
except Exception:
    df_fm = pd.read_csv('ferma_main.csv', sep=';')
    df_fd = pd.read_csv('ferma_dad.csv', sep=';')
    df_cb = pd.read_csv('cow_buy.csv', sep=';')

# %%
# обзор датасета df_fm
display(df_fm.info())
df_fm.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     634 non-null    int64
#  1   Удой, кг                               634 non-null    int64
#  2   ЭКЕ (Энергетическая кормовая единица)  634 non-null    object
#  3   Сырой протеин, г                       634 non-null    int64
#  4   СПО (Сахаро-протеиновое соотношение)   634 non-null    object
#  5   Порода                                 634 non-null    object
#  6   Тип пастбища                           634 non-null    object
#  7   порода папы_быка                       634 non-null    object
#  8   Жирность,%                             634 non-null    object
#  9   Белок,%                                634 non-null    object
# ...

# %%
# переименуем столбцы на более корреткные названия
df_fm.columns = ['id', 'milk_yield', 'efu', 'raw_protein', 'spr', 'breed', 'pasture', 'bull_breed', 'fat', 'protein', 'taste_milk', 'age']
df_fm.head()
# Out:
#    id  milk_yield   efu  raw_protein    spr            breed    pasture  \
# 0   1        5863  14,2         1743   0,89   Вис Бик Айдиал  Равнинное
# 1   2        5529  12,8         2138   0,89   Вис Бик Айдиал  Равнинные
# 2   3        5810    14         1854  0,885  РефлешнСоверинг  Холмистое
# 3   4        5895  12,4         2012  0,885  РефлешнСоверинг  Холмистое
# 4   5        5302  12,8         1675  0,885   Вис Бик Айдиал  Равнинные
#
#   bull_breed   fat protein taste_milk          age
# 0     Айдиал  3,58   3,076     вкусно  более_2_лет
# 1    Соверин  3,54   3,079     вкусно  менее_2_лет
# 2    Соверин  3,59   3,074  не вкусно  более_2_лет
# 3     Айдиал   3,4   3,075  не вкусно  более_2_лет
# 4    Соверин  3,73   3,073     вкусно  менее_2_лет

# %%
# обзор датасета df_fd
display(df_fd.info())
df_fd.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        629 non-null    int64
#  1   Имя Папы  629 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 10.0+ KB
# None
#    id  Имя Папы
# 0   1    Буйный
# 1   2  Соловчик
# 2   3     Барин
# 3   4    Буйный
# 4   5     Барин

# %%
# переименуем столбцы на более корреткные названия
df_fd.columns = ['id', 'name_bull']
df_fd.head()
# Out:
#    id name_bull
# 0   1    Буйный
# 1   2  Соловчик
# 2   3     Барин
# 3   4    Буйный
# 4   5     Барин

# %%
# обзор датасета df_cb
display(df_cb.info())
df_cb.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Порода                   20 non-null     object
#  1   Тип пастбища             20 non-null     object
#  2   порода папы_быка         20 non-null     object
#  3   Имя_папы                 20 non-null     object
#  4   Текущая_жирность,%       20 non-null     object
#  5   Текущий_уровень_белок,%  20 non-null     object
#  6   Возраст                  20 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB
# None
#             Порода Тип пастбища порода папы_быка  Имя_папы Текущая_жирность,%  \
# 0   Вис Бик Айдиал    холмистое           Айдиал  Геркулес               3,58
# 1   Вис Бик Айдиал    равнинное          Соверин    Буйный               3,54
# 2  РефлешнСоверинг    равнинное          Соверин     Барин               3,59
# ...

# %%
# переименуем столбцы на более корреткные названия
df_cb.columns = ['breed', 'pasture', 'bull_breed', 'name_bull', 'fat', 'protein', 'age']
df_cb.head()
# Out:
#              breed    pasture bull_breed name_bull   fat protein          age
# 0   Вис Бик Айдиал  холмистое     Айдиал  Геркулес  3,58   3,076  более_2_лет
# 1   Вис Бик Айдиал  равнинное    Соверин    Буйный  3,54   3,081  менее_2_лет
# 2  РефлешнСоверинг  равнинное    Соверин     Барин  3,59   3,074  более_2_лет
# 3  РефлешнСоверинг  холмистое     Айдиал    Буйный   3,4   3,061  более_2_лет
# 4  РефлешнСоверинг  равнинное     Айдиал    Буйный  3,64   3,074  более_2_лет

# %% [markdown]
# **Промежуточный вывод:**
#
# По результатам ознакомления с данными стало известно, что в распоряжении имеется 3 датасета с различной информацией о коровах, корме, молоке, быках. Были переименованы столбцы для более удобной работы с датасетом.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что приводишь названия столбцов к общепринятому виду

# %% [markdown]
# ## Предобработка данных.

# %% [markdown]
# Работа с датасетом `df_fm`.

# %%
df_fm.isna().sum()
# Out:
# id             0
# milk_yield     0
# efu            0
# raw_protein    0
# spr            0
# breed          0
# pasture        0
# bull_breed     0
# fat            0
# protein        0
# taste_milk     0
# age            0
# dtype: int64

# %%
df_fm.duplicated().sum()
# Out:
# 5

# %%
# удаляем дубликаты
df_fm = df_fm.drop_duplicates().reset_index(drop=True)
df_fm.duplicated().sum()
# Out:
# 0

# %%
# Обработка неявных дубликатов
display(df_fm['pasture'].unique())
df_fm.loc[df_fm['pasture'] == 'Равнинные', 'pasture'] = 'Равнинное'
df_fm['pasture'].value_counts()
# Out:
# array(['Равнинное', 'Равнинные', 'Холмистое'], dtype=object)
# Холмистое    351
# Равнинное    278
# Name: pasture, dtype: int64

# %%
# Обработка неявных дубликатов
display(df_fm['bull_breed'].unique())
df_fm.loc[df_fm['bull_breed'] == 'Айдиалл', 'bull_breed'] = 'Айдиал'
df_fm['bull_breed'].value_counts()
# Out:
# array(['Айдиал', 'Соверин', 'Айдиалл'], dtype=object)
# Айдиал     318
# Соверин    311
# Name: bull_breed, dtype: int64

# %%
add_dot = lambda x: x.replace(',', '.')

# %%
df_fm['efu'] = df_fm['efu'].agg(add_dot).astype('float')
df_fm['spr'] = df_fm['spr'].agg(add_dot).astype('float')
df_fm['fat'] = df_fm['fat'].agg(add_dot).astype('float')
df_fm['protein'] = df_fm['protein'].agg(add_dot).astype('float')
df_fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           629 non-null    int64
#  1   milk_yield   629 non-null    int64
#  2   efu          629 non-null    float64
#  3   raw_protein  629 non-null    int64
#  4   spr          629 non-null    float64
#  5   breed        629 non-null    object
#  6   pasture      629 non-null    object
#  7   bull_breed   629 non-null    object
#  8   fat          629 non-null    float64
#  9   protein      629 non-null    float64
#  10  taste_milk   629 non-null    object
#  11  age          629 non-null    object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 59.1+ KB

# %%
df_fm['pasture'] = df_fm['pasture'].agg(lambda x: x.lower())

# %% [markdown]
# Работа с датасетом `df_fd`.

# %%
df_fd.isna().sum()
# Out:
# id           0
# name_bull    0
# dtype: int64

# %%
df_fd.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Работа с датасетом `df_cb`.

# %%
df_cb.isna().sum()
# Out:
# breed         0
# pasture       0
# bull_breed    0
# name_bull     0
# fat           0
# protein       0
# age           0
# dtype: int64

# %%
df_cb.duplicated().sum()
# Out:
# 4

# %%
# удаляем дубликаты
df_cb = df_cb.drop_duplicates().reset_index(drop=True)
df_cb.duplicated().sum()
# Out:
# 0

# %%
df_cb['fat'] = df_cb['fat'].agg(add_dot).astype('float')
df_cb['protein'] = df_cb['protein'].agg(add_dot).astype('float')
df_cb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   breed       16 non-null     object
#  1   pasture     16 non-null     object
#  2   bull_breed  16 non-null     object
#  3   name_bull   16 non-null     object
#  4   fat         16 non-null     float64
#  5   protein     16 non-null     float64
#  6   age         16 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 1.0+ KB

# %% [markdown]
# **Промежуточный вывод:**
#
# По результатам предобработки данных была проведена работа по проверке данных на пропуски, по очистке данных от дубликатов, по преобразованию типов данных.

# %% [markdown]
# ## Исследовательский анализ данных.

# %% [markdown]
# ### ferma_main

# %%
df_fm.describe()
# Out:
#           id  milk_yield    efu  raw_protein    spr    fat  protein
# count 629.00      629.00 629.00       629.00 629.00 629.00   629.00
# mean  315.00    6,188.75  14.54     1,923.36   0.91   3.60     3.08
# std   181.72    1,644.80   1.31       182.96   0.03   0.17     0.00
# min     1.00    5,204.00  10.90     1,660.00   0.84   2.99     3.07
# 25%   158.00    5,751.00  13.50     1,771.00   0.89   3.59     3.07
# 50%   315.00    6,133.00  14.70     1,888.00   0.93   3.65     3.08
# 75%   472.00    6,501.00  15.60     2,062.00   0.94   3.72     3.08
# max   629.00   45,616.00  16.80     2,349.00   0.96   3.75     3.08

# %%
df_fm.describe(include='object')
# Out:
#                  breed    pasture bull_breed taste_milk          age
# count              629        629        629        629          629
# unique               2          2          2          2            2
# top     Вис Бик Айдиал  холмистое     Айдиал     вкусно  более_2_лет
# freq               373        351        318        371          519

# %% [markdown]
# #### milk_yield

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.boxplot(df_fm['milk_yield'], vert=False)
ax.set_xlabel('Удой, кг.')
ax.set_ylabel('item')
ax.set_title('Удой коровы в килограммах')

plt.show()

# %% [markdown]
# На графике выше видна явная ошибка. Её следует изменить на медианное значение столбца `milk_yield`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Правильно, такие выбросы лучше сразу справлять, можно даже удалить

# %%
display(df_fm[df_fm['milk_yield'] == df_fm['milk_yield'].max()])
df_fm.loc[df_fm['milk_yield'] == 45616, 'milk_yield'] = int(df_fm['milk_yield'].median())
display(df_fm[df_fm['id'] == 17])
# Out:
#     id  milk_yield   efu  raw_protein  spr           breed    pasture  \
# 16  17       45616 11.50         1675 0.93  Вис Бик Айдиал  холмистое
#
#    bull_breed  fat  protein taste_milk          age
# 16     Айдиал 3.22     3.08     вкусно  более_2_лет
#     id  milk_yield   efu  raw_protein  spr           breed    pasture  \
# 16  17        6133 11.50         1675 0.93  Вис Бик Айдиал  холмистое
#
#    bull_breed  fat  protein taste_milk          age
# 16     Айдиал 3.22     3.08     вкусно  более_2_лет

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(df_fm['milk_yield'], bins=20, rwidth=0.8)
ax.set_xlabel('удой, кг.')
ax.set_ylabel('количество')
ax.set_title('Гистограмма распределения удоя коров в килограммах')

plt.show()

# %% [markdown]
# #### efu

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.boxplot(df_fm['efu'], vert=False)

ax.set_xlabel('Энергетическая кормовая единица')
ax.set_ylabel('item')
ax.set_title('Энергетическая коромвая единица')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(df_fm['efu'], bins=10, rwidth=0.8)

ax.set_xlabel('Энергетическая кормовая единица')
ax.set_ylabel('количество')
ax.set_title('Гистограмма распределения энергетической коромвой единицы')

plt.show()

# %% [markdown]
#  Аномалий и выбрососв в столбце `efu` не обнаружено.

# %% [markdown]
# ####  raw_protein

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.boxplot(df_fm['raw_protein'], vert=False)

ax.set_xlabel('Сырой протеин в граммах')
ax.set_ylabel('item')
ax.set_title('Сырой протеин в корме')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.hist(df_fm['raw_protein'], bins=10, rwidth=0.8)

ax.set_xlabel('сырой проетин в граммах')
ax.set_ylabel('количество')
ax.set_title('Гистограмма распределения сырого протеина в корме в граммах')

plt.show()

# %% [markdown]
#  Аномалий и выбрососв в столбце `raw_protein` не обнаружено.

# %% [markdown]
# #### spr

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.boxplot(df_fm['spr'], vert=False)

ax.set_xlabel('Сахаро-протеиновое соотношение')
ax.set_ylabel('item')
ax.set_title('Сахаро-протеиновое соотношение')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(df_fm['spr'], bins=10, rwidth=0.8)

ax.set_xlabel('Сахаро-протеиновое соотношение')
ax.set_ylabel('количество')
ax.set_title('Гистограмма распределения сахаро-протеинового соотношения')

plt.show()

# %% [markdown]
# Аномалий и выбрососв в столбце `spr` не обнаружено. Хотя гистограмма выглядит необычно.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Обрати внимание, у тебя тебя несколько раз повторяется практически одинаковый код. Для соблюдения принципов ООП, лучше создать функцию, и вызывать её в случае необходимости.

# %% [markdown]
# #### fat

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.boxplot(df_fm['fat'], vert=False)

ax.set_xlabel('Жирность в процентах')
ax.set_ylabel('item')
ax.set_title('Содержание жиров в молоке')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(df_fm['fat'], bins=10, rwidth=0.8)

ax.set_xlabel('Жирность в процентах')
ax.set_ylabel('Количество')
ax.set_title('Гистограмма рапсределения содержания жиров в молоке')

plt.show()

# %% [markdown]
# На графиках видны выбросы по нижней границе данных. Гистограмма распределения тоже не выглядит как нормальное распределение.

# %% [markdown]
# #### protein

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.boxplot(df_fm['protein'], vert=False)

ax.set_xlabel('Белок в процентах')
ax.set_ylabel('item')
ax.set_title('Содержание белков в молоке')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(df_fm['protein'], bins=10, rwidth=0.8)

ax.set_xlabel('Содержание белков в молоке')
ax.set_ylabel('Количество')
ax.set_title('Гистограмма распределения содержания белков в молоке')

plt.show()

# %% [markdown]
# На графике выше видны 3 выброса. Гистограмма распределения выглядит приемлемо.

# %% [markdown]
# #### breed

# %%
a = df_fm['breed'].value_counts().reset_index()
a.columns = ['breed', 'count']

fig, ax = plt.subplots()


ax.pie(a['count'], labels=a['breed'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма породы коровы')

plt.show()

# %% [markdown]
# #### pasture

# %%
a = df_fm['pasture'].value_counts().reset_index()
a.columns = ['pasture', 'count']


fig, ax = plt.subplots()

ax.pie(a['count'], labels=a['pasture'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма типа пастбищ')

plt.show()

# %% [markdown]
# #### bull_breed

# %%
a = df_fm['bull_breed'].value_counts().reset_index()
a.columns = ['bull_breed', 'count']

fig, ax = plt.subplots()

ax.pie(a['count'], labels=a['bull_breed'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма породы быков')

plt.show()

# %% [markdown]
# #### taste_milk

# %%
a = df_fm['taste_milk'].value_counts().reset_index()
a.columns = ['taste_milk', 'count']

fig, ax = plt.subplots()

ax.pie(a['count'], labels=a['taste_milk'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма вкуса молока')

plt.show()

# %% [markdown]
# #### age

# %%
a = df_fm['age'].value_counts().reset_index()
a.columns = ['age', 'count']

fig, ax = plt.subplots()

ax.pie(a['count'], labels=a['age'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма типа возраста коров')

plt.show()

# %% [markdown]
# ### ferma_dad

# %%
a = df_fd['name_bull'].value_counts().reset_index()
a.columns = ['name', 'count']

fig, ax = plt.subplots()

ax.pie(a['count'], labels=a['name'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма имён быков')

plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Для категориальных данных кроме круговых диграмм можно построить ещё и столбчатые

# %% [markdown]
# ### cow_buy

# %%
df_cb.describe()
# Out:
#         fat  protein
# count 16.00    16.00
# mean   3.57     3.07
# std    0.14     0.01
# min    3.34     3.05
# 25%    3.42     3.06
# 50%    3.58     3.07
# 75%    3.69     3.08
# max    3.77     3.08

# %%
df_cb.describe(include='object')
# Out:
#                  breed    pasture bull_breed name_bull          age
# count               16         16         16        16           16
# unique               2          2          2         4            2
# top     Вис Бик Айдиал  холмистое    Соверин    Буйный  более_2_лет
# freq                 8          8         10         7           11

# %% [markdown]
# #### fat

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.boxplot(df_cb['fat'], vert=False)

ax.set_xlabel('Жирность в процентах')
ax.set_ylabel('item')
ax.set_title('Содержание жиров в молоке')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(df_cb['fat'], bins=4, rwidth=0.8)

ax.set_xlabel('Жирность в процентах')
ax.set_ylabel('Количество')
ax.set_title('Гистограмма рапсределения содержания жиров в молоке')

plt.show()

# %% [markdown]
# #### protein

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.boxplot(df_cb['protein'], vert=False)

ax.set_xlabel('Белок в процентах')
ax.set_ylabel('item')
ax.set_title('Содержание белков в молоке')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(df_cb['protein'], bins=10, rwidth=0.8)

ax.set_xlabel('Содержание белков в молоке')
ax.set_ylabel('Количество')
ax.set_title('Гистограмма распределения содержания белков в молоке')

plt.show()

# %% [markdown]
# Из-за немногочисленной быроки данных графики выглядят необычно.

# %% [markdown]
# #### breed

# %%
a = df_cb['breed'].value_counts().reset_index()
a.columns = ['breed', 'count']

fig, ax = plt.subplots()


ax.pie(a['count'], labels=a['breed'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма породы коровы')

plt.show()

# %% [markdown]
# #### pasture

# %%
a = df_cb['pasture'].value_counts().reset_index()
a.columns = ['pasture', 'count']


fig, ax = plt.subplots()

ax.pie(a['count'], labels=a['pasture'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма типа пастбищ')

plt.show()

# %% [markdown]
# #### bull_breed

# %%
a = df_cb['bull_breed'].value_counts().reset_index()
a.columns = ['bull_breed', 'count']

fig, ax = plt.subplots()

ax.pie(a['count'], labels=a['bull_breed'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма породы быков')

plt.show()

# %% [markdown]
# #### name_bull

# %%
a = df_cb['name_bull'].value_counts().reset_index()
a.columns = ['name', 'count']

fig, ax = plt.subplots()

ax.pie(a['count'], labels=a['name'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма имён быков')

plt.show()

# %% [markdown]
# #### age

# %%
a = df_cb['age'].value_counts().reset_index()
a.columns = ['age', 'count']

fig, ax = plt.subplots()

ax.pie(a['count'], labels=a['age'], autopct='%1.1f%%')

ax.set_title('Круговая диаграмма типа возраста коров')

plt.show()

# %% [markdown]
# **Промежуточный вывод:**
#
# По результатам проведения исследовательского анализа:
#
# - визуализированны количественные данные датасета `df_fm`.
# - визуализированны категориальные данные датасета `df_fm`.
# - проведён исследовательский анализ датасета `df_fd`.
# - проведён исследовательский анализ датасета `df_cb`.

# %% [markdown]
# ## корреляционный анализ признаков в датасете `ferma_main.csv`

# %%
sns.heatmap(df_fm.corr(), annot=True, linewidth=.5)
plt.show()

# %%
def get_scatter(num_ax, y, type):
    '''Построение диаграмм рассеяния для удоя коровы в киллограммах с целевым признаком и различными категориальными метками'''
    xy = ['milk_yield', y]
    for i in df_fm[type].unique():
        a = df_fm.loc[df_fm[type] == i, xy]
        ax[num_ax].scatter(a['milk_yield'], a[y], alpha=0.7, s=30, label=i)
        ax[num_ax].set_xlabel('milk_yield')
        ax[num_ax].set_ylabel(y)
    ax[num_ax].legend()

# %%
fig, ax = plt.subplots(1, 5, figsize=(21, 4))
plt.suptitle('Диаграммы рассеяния удоя коровы в киллограммах и показателя питательности корма коровы')

ax[0].set_title('Порода коровы')
get_scatter(0, 'efu', 'breed')

ax[1].set_title('Тип пастбища')
get_scatter(1, 'efu', 'pasture')

ax[2].set_title('Порода быка')
get_scatter(2, 'efu', 'bull_breed')


ax[3].set_title('Вкус молока')
get_scatter(3, 'efu', 'taste_milk')


ax[4].set_title('возраст коровы')
get_scatter(4, 'efu', 'age')


plt.show()

# %% [markdown]
# В целом, с увеличением показателя питательности корма коровы увеличивается и удой, но это не совсем работает для коров с возрастом менее 2 лет. У них удой стабильный вне зависимости от показателя питательности корма.

# %%
fig, ax = plt.subplots(1, 5, figsize=(21, 4))
plt.suptitle('Диаграммы рассеяния удоя коровы в киллограммах и содержимого сырого протеина в корме коровы')

ax[0].set_title('Порода коровы')
get_scatter(0, 'raw_protein', 'breed')

ax[1].set_title('Тип пастбища')
get_scatter(1, 'raw_protein', 'pasture')

ax[2].set_title('Порода быка')
get_scatter(2, 'raw_protein', 'bull_breed')


ax[3].set_title('Вкус молока')
get_scatter(3, 'raw_protein', 'taste_milk')


ax[4].set_title('возраст коровы')
get_scatter(4, 'raw_protein', 'age')


plt.show()

# %% [markdown]
# У коров с возрастом менее 2 лет удой не зависит от содержимого сырого протеина в корме.

# %%
fig, ax = plt.subplots(1, 5, figsize=(21, 4))
plt.suptitle('Диаграммы рассеяния удоя коровы в киллограммах и отношения сахара к протеину в корме коровы')

ax[0].set_title('Порода коровы')
get_scatter(0, 'spr', 'breed')

ax[1].set_title('Тип пастбища')
get_scatter(1, 'spr', 'pasture')

ax[2].set_title('Порода быка')
get_scatter(2, 'spr', 'bull_breed')


ax[3].set_title('Вкус молока')
get_scatter(3, 'spr', 'taste_milk')


ax[4].set_title('возраст коровы')
get_scatter(4, 'spr', 'age')


plt.show()

# %% [markdown]
# Отношение сахара к протеину в корме выше 0.92 влияет на удой. Коровы с возрастом менее 2 лет обычно не дают более 5750 кг молока.

# %%
fig, ax = plt.subplots(1, 5, figsize=(21, 4))
plt.suptitle('Диаграммы рассеяния удоя коровы в киллограммах и содержания жиров в молоке')

ax[0].set_title('Порода коровы')
get_scatter(0, 'fat', 'breed')

ax[1].set_title('Тип пастбища')
get_scatter(1, 'fat', 'pasture')

ax[2].set_title('Порода быка')
get_scatter(2, 'fat', 'bull_breed')


ax[3].set_title('Вкус молока')
get_scatter(3, 'fat', 'taste_milk')


ax[4].set_title('возраст коровы')
get_scatter(4, 'fat', 'age')


plt.show()

# %% [markdown]
# Содрежание в молоке в основном не влияет на удой. У коров с возрастом менее 2 лет всё также маленький удой.

# %%
fig, ax = plt.subplots(1, 5, figsize=(21, 4))
plt.suptitle('Диаграммы рассеяния удоя коровы в киллограммах и содержания белков в молоке')

ax[0].set_title('Порода коровы')
get_scatter(0, 'protein', 'breed')

ax[1].set_title('Тип пастбища')
get_scatter(1, 'protein', 'pasture')

ax[2].set_title('Порода быка')
get_scatter(2, 'protein', 'bull_breed')


ax[3].set_title('Вкус молока')
get_scatter(3, 'protein', 'taste_milk')


ax[4].set_title('возраст коровы')
get_scatter(4, 'protein', 'age')


plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Пекрасно иследован массив, молодец, графики, хорошие, очень репрезентативные! Однако легенду графиков стоит вывести более крупным шрифтом

# %% [markdown]
# Удой молока также не зависит и от содержания белков в молоке. Молодые коровы не дают много молока.

# %% [markdown]
# **Промежуточный вывод:**
#
# - Линейная связь с удоем коровы прослеживается у содержания сырого протеина в корме и у показателся питательности корма.
# - Молодые коровы (до 2 лет) как правило дают меньший удой, чем старшие коровы.
# - Нелинейные связи между целевым и входными признаками присутствуют.
# - Необходимость введения дополнительных признаков пока не определена.
# - Некоторая мультиколлинеарность наблюдается у efu и fat, efu и spr, spr и fat.

# %% [markdown]
# ## Задача регрессии.

# %%
# создание класса, описывающего модель

class LinearModel:
    def __init__(self, r2, residuals, hist, scatter, mse, mae, rmse):
        self.r2 = r2
        self.residuals = residuals
        self.hist = hist
        self.scatter = scatter
        self.mse = mse
        self.mae = mae
        self.rmse = rmse

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Круто, что пишешь свои классы, и комментируешь их, советую дописать к ним [docstrings](https://www.programiz.com/python-programming/docstrings).

# %% [markdown]
# ### первая модель

# %%
df_fm.head()
# Out:
#    id  milk_yield   efu  raw_protein  spr            breed    pasture  \
# 0   1        5863 14.20         1743 0.89   Вис Бик Айдиал  равнинное
# 1   2        5529 12.80         2138 0.89   Вис Бик Айдиал  равнинное
# 2   3        5810 14.00         1854 0.89  РефлешнСоверинг  холмистое
# 3   4        5895 12.40         2012 0.89  РефлешнСоверинг  холмистое
# 4   5        5302 12.80         1675 0.89   Вис Бик Айдиал  равнинное
#
#   bull_breed  fat  protein taste_milk          age
# 0     Айдиал 3.58     3.08     вкусно  более_2_лет
# 1    Соверин 3.54     3.08     вкусно  менее_2_лет
# 2    Соверин 3.59     3.07  не вкусно  более_2_лет
# 3     Айдиал 3.40     3.08  не вкусно  более_2_лет
# 4    Соверин 3.73     3.07     вкусно  менее_2_лет

# %%
X = df_fm[['efu', 'raw_protein', 'spr', 'breed', 'pasture', 'bull_breed', 'age']]
y = df_fm['milk_yield']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=7)

# %%
encoder = OneHotEncoder(sparse=False)

X_train_ohe = encoder.fit_transform(X_train[['breed', 'pasture', 'bull_breed', 'age']])
X_test_ohe = encoder.transform(X_test[['breed', 'pasture', 'bull_breed', 'age']])

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train[['efu', 'raw_protein', 'spr',]])
X_test_scaled = scaler.transform(X_test[['efu', 'raw_protein', 'spr']])

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Верно жирность и белок не надо использовать в модели: эти факторы, не влияют на “удой”. Это уже признаки самого молока

# %%
X_train_prep = np.concatenate((X_train_scaled, X_train_ohe), axis=1)
X_test_prep = np.concatenate((X_test_scaled, X_test_ohe), axis=1)

# %%
model_lr = LinearRegression()
model_lr = model_lr.fit(X_train_prep, y_train)

# %%
predictions = model_lr.predict(X_test_prep)

# %%
r2 = r2_score(y_test, predictions)
r2
# Out:
# 0.8284729036015659

# %%
residuals = y_test - predictions

# %%
fig, ax = plt.subplots(figsize=(15,5))

def hist(ax, residuals):
    ax.hist(residuals, bins=100, rwidth=0.8)
    
    ax.set_title('Гистограмма остатков первой модели')
    ax.set_xlabel('Значение остатков')
    ax.set_ylabel('Количество')
    
hist(ax, residuals)

plt.show()

# %%
sub, ax = plt.subplots()

def scat(ax, residuals):
    ax.scatter(y_test, residuals, alpha=0.7, s=30)
    
    ax.set_xlabel('Прогнозные значения первой модели')
    ax.set_ylabel('Остатки модели')
    ax.set_title('Диаграмма рассеивания')

scat(ax, residuals)   

plt.show()

# %%
# Создание экземпляра класса первой модели
m1 = LinearModel(r2, residuals, hist, scat, mean_squared_error(y_test, predictions), mean_absolute_error(y_test, predictions), mean_squared_error(y_test, predictions, squared=False))

# %% [markdown]
# **Вывод по обученой модели:**
# - Значение R2 равно 0.82.
# - Распределение на гистограмме остатков модели не равномерное. Видны несколько пиков, что говорит о ненормальном распределении.
# - Диаграмма рассеивания показвает, что модель нестабильна. Требуется трансофрмация данных и введение новых признаков.
# - Дополнительные исследования нужны.

# %% [markdown]
# ### вторая модель

# %%
X = df_fm[['efu', 'raw_protein', 'spr', 'breed', 'pasture', 'bull_breed', 'age']]
y = df_fm['milk_yield']

# %%
# создание категориального столбца из spr
trans_spr = lambda x: 1 if x > 0.92 else 0

X['spr'] = X['spr'].agg(trans_spr)

# %%
# Преобразование признака efu

trans_efu = lambda x: x**2

X['efu_qrt'] = X['efu'].agg(trans_efu)

X = X.drop('efu', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=7)

# %%
encoder = OneHotEncoder(sparse=False)

X_train_ohe = encoder.fit_transform(X_train[['breed', 'pasture', 'bull_breed', 'age']])
X_test_ohe = encoder.transform(X_test[['breed', 'pasture', 'bull_breed', 'age']])

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train[['efu_qrt', 'raw_protein', 'spr',]])
X_test_scaled = scaler.transform(X_test[['efu_qrt', 'raw_protein', 'spr']])

# %%
X_train_prep = np.concatenate((X_train_scaled, X_train_ohe), axis=1)
X_test_prep = np.concatenate((X_test_scaled, X_test_ohe), axis=1)

# %%
model_lr = LinearRegression()
model_lr = model_lr.fit(X_train_prep, y_train)

# %%
predictions = model_lr.predict(X_test_prep)

# %%
r2 = r2_score(y_test, predictions)
r2
# Out:
# 0.8532471803307585

# %%
residuals = y_test - predictions

# %%
fig, ax = plt.subplots(figsize=(15,5))

def hist(ax, residuals):
    ax.hist(residuals, bins=100, rwidth=0.8)

    ax.set_title('Гистограмма остатков модели')
    ax.set_xlabel('Значение остатков')
    ax.set_ylabel('Количество')

hist(ax, residuals)   
    
plt.show()

# %%
sub, ax = plt.subplots()

def scat(ax, residuals):
    ax.scatter(y_test, residuals, alpha=0.7, s=30)

    ax.set_xlabel('Прогнозные значения модели')
    ax.set_ylabel('Остатки модели')
    ax.set_title('Диаграмма рассеивания')

scat(ax, residuals)
    
plt.show()

# %%
# Создание экземпляра класса первой модели
m2 = LinearModel(r2, residuals, hist, scat, mean_squared_error(y_test, predictions), mean_absolute_error(y_test, predictions), mean_squared_error(y_test, predictions, squared=False))

# %% [markdown]
# **Вывод по обученой модели:**
# - Значение R2 равно 0.85.
# - Распределение остатков второй модели на гистограмме более равномерное, чем первой модели. Однако распределение ещё нельзя назвать нормальным.
# - Диаграмма рассеивания второй модели не сильно отличается от первой модели. Вторая модель также нестабильна.
# - Требуются дополнительные исследования.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Всё верно, если убрать нелинейность модель выдает более точные результаты

# %% [markdown]
# ### Третья модель

# %%
a = df_fm.merge(right=df_fd, on='id', how='left')
X = a.drop(['milk_yield', 'id', 'fat', 'protein', 'taste_milk'], axis=1)
y = a['milk_yield']

# создание категориального столбца из spr
trans_spr = lambda x: 1 if x > 0.92 else 0
X['spr'] = X['spr'].agg(trans_spr)

# Преобразование признака efu
trans_efu = lambda x: x**2
X['efu_qrt'] = X['efu'].agg(trans_efu)
X = X.drop('efu', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=7)

# %%
encoder = OneHotEncoder(sparse=False)

X_train_ohe = encoder.fit_transform(X_train[['breed', 'pasture', 'bull_breed', 'age', 'name_bull']])
X_test_ohe = encoder.transform(X_test[['breed', 'pasture', 'bull_breed', 'age', 'name_bull']])

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train[['efu_qrt', 'raw_protein', 'spr',]])
X_test_scaled = scaler.transform(X_test[['efu_qrt', 'raw_protein', 'spr']])

# %%
X_train_prep = np.concatenate((X_train_scaled, X_train_ohe), axis=1)
X_test_prep = np.concatenate((X_test_scaled, X_test_ohe), axis=1)

# %%
model_lr = LinearRegression()
model_lr = model_lr.fit(X_train_prep, y_train)

# %%
predictions = model_lr.predict(X_test_prep)

# %%
r2 = r2_score(y_test, predictions)
r2
# Out:
# 0.8660038084575326

# %%
residuals = y_test - predictions

# %%
fig, ax = plt.subplots(figsize=(15,5))

def hist(ax, residuals):
    ax.hist(residuals, bins=100, rwidth=0.8)

    ax.set_title('Гистограмма остатков модели')
    ax.set_xlabel('Значение остатков')
    ax.set_ylabel('Количество')

hist(ax, residuals)
    
plt.show()

# %%
sub, ax = plt.subplots()

def scat(ax, residuals):
    ax.scatter(y_test, residuals, alpha=0.7, s=30)

    ax.set_xlabel('Прогнозные значения модели')
    ax.set_ylabel('Остатки модели')
    ax.set_title('Диаграмма рассеивания')

scat(ax, residuals)
    
plt.show()

# %%
# Создание экземпляра класса первой модели
m3 = LinearModel(r2, residuals, hist, scat, mean_squared_error(y_test, predictions), mean_absolute_error(y_test, predictions), mean_squared_error(y_test, predictions, squared=False))

# %% [markdown]
# **Вывод по обученой модели:**
# - Значение R2 равно 0.86.
# - Гистограмма остатков модели распределена ненормально.
# - Диаграмма рассеивания показывает, что модель, как и все предыдущие, нестабильная.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Да, с новыми признаками модель стала работать ещё лучше

# %% [markdown]
# ### Сравнение качества моделей

# %%
print(f'''Значение r2:
        - первой модели: {m1.r2}
        - второй модели: {m2.r2}
        - третьей модели: {m3.r2}''')
# Out:
# Значение r2:
#         - первой модели: 0.8284729036015659
#         - второй модели: 0.8532471803307585
#         - третьей модели: 0.8660038084575326

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 4))

m1.hist(ax[0], m1.residuals)
m2.hist(ax[1], m2.residuals)
m3.hist(ax[2], m3.residuals)

plt.suptitle('Сравнение гистограмм остатков моделей', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 4))

m1.scatter(ax[0], m1.residuals)
m2.scatter(ax[1], m2.residuals)
m3.scatter(ax[2], m3.residuals)

plt.suptitle('Сравнение диаграмм рассеивания остатков моделей', fontsize=15)

plt.show()

# %%
print(f'''Значение метрики mse:
      - первой модели {m1.mse}
      - второй модели {m2.mse}
      - третьей модели {m3.mse}''')
# Out:
# Значение метрики mse:
#       - первой модели 41920.01241489504
#       - второй модели 35865.35393898046
#       - третьей модели 32747.72400951206

# %%
print(f'''Значение метрики mae:
      - первой модели {m1.mae}
      - второй модели {m2.mae}
      - третьей модели {m3.mae}''')
# Out:
# Значение метрики mae:
#       - первой модели 161.14655160170955
#       - второй модели 144.46192400450693
#       - третьей модели 139.74760100821257

# %%
print(f'''Значение метрики rmse:
      - первой модели {m1.rmse}
      - второй модели {m2.rmse}
      - третьей модели {m3.rmse}''')
# Out:
# Значение метрики rmse:
#       - первой модели 204.743772591244
#       - второй модели 189.38150368761058
#       - третьей модели 180.9633222769522

# %% [markdown]
# ### Прогнозирование лучшей модели

# %% [markdown]
# **Лучшая модель.**
#
# По всем метрикам лучшая модель - третья. Третья модель ошибается примерно на 140-181 кг молока удоя примерно в 14 % случаев.

# %%
print(f'Доверительный интервал прогноза модели от {round(np.quantile(predictions, 0.05))} кг. до {round(np.quantile(predictions, 0.95))} кг.')
# Out:
# Доверительный интервал прогноза модели от 5379 кг. до 6690 кг.

# %%
X = df_cb[['breed', 'pasture', 'bull_breed', 'age', 'name_bull']]
X.insert(0, 'raw_protein', df_fm['raw_protein'].mean() * 1.05)
X.insert(1, 'spr', 1) # так как df_fm['spr'].mean() * 1.05 больше 0.92
X['efu_qrt'] = (df_fm['efu'].mean() * 1.05) **2

# %%
X_ohe = encoder.transform(X[['breed', 'pasture', 'bull_breed', 'age', 'name_bull']])
X_scaled = scaler.transform(X[['efu_qrt', 'raw_protein', 'spr']])
X_prep = np.concatenate((X_scaled, X_ohe), axis=1)

# %%
predictions = model_lr.predict(X_prep)
df_cb_milk_yield = predictions

# %%
fig, ax = plt.subplots(figsize=(15, 3))

plot = ax.bar(range(16), sorted(predictions), tick_label=sorted([round(_) for _ in predictions]))
ax.set(xlabel='ID', ylabel='удой в кг.', title='Предсказаные значения удоя коров в киллограммах')

plt.show()

# %% [markdown]
# **Промежуточный вывод.**
#
# По итогам проведения задачи регрессии:
# - обучены три регрессионые модели для предсказания удоя коров
# - проанализированны остатки моделей и их метрики
# - выбрана лучшая модель и сделаны целевые предсказания
# - Предсказаные значения являются наиболее популярными значениями в текущем стаде фермера

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Линейная регрессия сделана хорошо

# %% [markdown]
# ## Задача классификации.

# %%
X = a[['breed', 'pasture', 'bull_breed', 'name_bull', 'fat', 'protein', 'age']]
y = df_fm['taste_milk']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=3314)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train[['fat', 'protein']])
X_test_scaled = scaler.transform(X_test[['fat', 'protein']])

# %%
encoder = OneHotEncoder(sparse=False)

X_train_ohe = encoder.fit_transform(X_train[['breed', 'pasture', 'bull_breed', 'name_bull', 'age']])
X_test_ohe = encoder.transform(X_test[['breed', 'pasture', 'bull_breed', 'name_bull', 'age']])

# %%
X_train_prep = np.concatenate((X_train_scaled, X_train_ohe), axis=1)
X_test_prep = np.concatenate((X_test_scaled, X_test_ohe), axis=1)

# %%
clf = LogisticRegression()
clf = clf.fit(X_train_prep, y_train)
y_pred = clf.predict(X_test_prep)

# %%
tr = lambda x: 0 if x == 'не вкусно' else 1
t = [0 if x == 'не вкусно' else 1 for x in y_test]
p = [0 if x == 'не вкусно' else 1 for x in y_pred]
ac = accuracy_score(y_test, y_pred)
re = recall_score(t, p)
pr = precision_score(t, p)
print(f'''Метрики логистисеской модели:
    accuracy = {ac}
    recall = {re}
    precision = {pr}''')
# Out:
# Метрики логистисеской модели:
#     accuracy = 0.7215189873417721
#     recall = 0.8921568627450981
#     precision = 0.7338709677419355

# %%
cm = confusion_matrix(y_test, y_pred, labels=['не вкусно', 'вкусно'])
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r', xticklabels=['не вкусно', 'вкусно'], yticklabels=['не вкусно', 'вкусно'])
plt.ylabel('True label')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# На данном этапе всё  сделано верно

# %% [markdown]
# ### Подбор порога классификации.

# %%
y_proba = clf.predict_proba(X_test_prep)[:,0]

# %%
ms = pd.DataFrame([[x, y] for x, y in zip(t, y_proba)], columns=['y_valid', 'y_proba']).sort_values(by='y_proba',ascending=False)

# %%
thresholds = [round(i,2) for i in np.linspace(0.1,1,num = 16,endpoint=False)]
columns = []
for i in thresholds:
    columns.append('y_'+str(i))
    ms['y_'+str(i)] = ms['y_proba'].apply(lambda x: 1 if x >= i else 0)

# %%
s = []
for i in columns:
    s.append([i, precision_score(ms['y_valid'], ms[i]), recall_score(ms['y_valid'], ms[i]), accuracy_score(ms['y_valid'], ms[i])])
pd.DataFrame(s, columns=['index', 'precision', 'recall', 'accuracy'])
# Out:
#      index  precision  recall  accuracy
# 0    y_0.1       0.65    1.00      0.65
# 1   y_0.16       0.65    1.00      0.65
# 2   y_0.21       0.65    1.00      0.65
# 3   y_0.27       0.65    1.00      0.65
# 4   y_0.32       0.65    1.00      0.65
# 5   y_0.38       0.67    0.99      0.68
# 6   y_0.44       0.71    0.96      0.72
# 7   y_0.49       0.72    0.90      0.71
# 8   y_0.55       0.78    0.73      0.69
# 9   y_0.61       0.82    0.48      0.59
# 10  y_0.66       0.89    0.31      0.53
# 11  y_0.72       0.75    0.03      0.37
# 12  y_0.78       0.00    0.00      0.35
# 13  y_0.83       0.00    0.00      0.35
# 14  y_0.89       0.00    0.00      0.35
# 15  y_0.94       0.00    0.00      0.35

# %%
cm = confusion_matrix(ms['y_valid'], ms['y_0.66'])
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r', xticklabels=['не вкусно', 'вкусно'], yticklabels=['не вкусно', 'вкусно'])
plt.ylabel('True label')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# Изначально модель имела следующие показатели:
# - порог модели = 0.5
# - accuracy = 0.72
# - recall = 0.89
# - precision = 0.73
#
# Теперь модель имеет следущие показатели:
# - порог модели = 0.66
# - accuracy = 0.53
# - recall = 0.31
# - precision = 0.89

# %% [markdown]
# ### Целевое предсказание

# %%
def custom_predict(X, threshold):
    '''Предсказание значений с установленным порогом классификации'''
    probs = clf.predict_proba(X) 
    return (probs[:, 0] > threshold).astype(int)

# %%
b = df_cb
b_scaled = scaler.transform(b[['fat', 'protein']])
b_ohe = encoder.transform(b[['breed', 'pasture', 'bull_breed', 'name_bull', 'age']])
b_prep = np.concatenate((b_scaled, b_ohe), axis=1)

# %%
pred = custom_predict(b_prep, 0.66)
df_cb_taste_milk = ['не вкусно' if _ == 0 else 'вкусно' for _ in pred]

# %%
fig, ax = plt.subplots(figsize=(5,3))

ax.bar(['не вкусно', 'вкусно'], [pred.size - sum(pred), sum(pred)])
ax.set(ylabel='количество', title='Распределение предсказаний модели')

plt.show()

# %% [markdown]
# **Промежуточный вывод.**
#
# По итогам проведения задачи классификации:
# - была обучена тестовая модель классификации
# - проведено исследование по улучшению модели
# - сделано предсказание на целевом датасете

# %% [markdown]
# ## Итоговые выводы

# %%
df_cb['milk_yield'] = df_cb_milk_yield
df_cb['taste_milk'] = df_cb_taste_milk

# %%
df_cb.query('taste_milk == "вкусно" and milk_yield > 6000')
# Out:
#              breed    pasture bull_breed name_bull  fat  protein          age  \
# 0   Вис Бик Айдиал  холмистое     Айдиал  Геркулес 3.58     3.08  более_2_лет
# 13  Вис Бик Айдиал  холмистое    Соверин  Соловчик 3.73     3.08  более_2_лет
#
#     milk_yield taste_milk
# 0     6,576.00     вкусно
# 13    6,349.24     вкусно

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Такими буренками фермер точно будет доволен!

# %% [markdown]
# Фермер с минимальным риском для себя из стада на продажу исходя из прогнозов моделей сможет купить двух коров.
# По прогнозам регрессионной модели все коровы из стада на продажу дают более 6000 кг. удоя ежегодно. Но, по предсказаниям логистической модели, только две коровы имеют вкусное молоко. Это было сделано преднамеренно, чтобы минимизировать риски для фермера.

# %% [markdown]
# Для улучшения качества регрессионной модели были использованы добавление новых признаков, преобразование значений для устранения нелинейности.
#
# Результаты регрессионной модели можно улучшить. Для этого нужно стабилизировать значение дисперсии остатков. А также можно нормализовать распределение остатков.

# %% [markdown]
# Для моделлей классификации при анализе рисков важны все метрики, а именно precision, recall, accuracy. Accuracy  поможет регулировать порог/уровень предсказания модели (TruePositive, TrueNegative), а precision или recall поможет свести предсказания модели в наиболее выгодную для конкретной задачи сторону.

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект, было приятно его проверять! В него действительно вложено много сил и времени! Есть несколько важных моментов, которые я отметил и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * Использование методов из программы курса на высоте. Хорошая работа!
# * Работа проделана действительно масштабная и видно, что ты очень стараешься!
# * Отлично разработаны функции и класс!
#
# **Отличная работа! Если есть какие-то вопросы пиши, рад буду помочь!**😉
# Если вопросов нет, присылай работу ещё раз, буду рад её принять.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Доброго времени.
# Я удивлён, что проект с первого раза оказался приемлемым. У меня появился шанс нагнать программу, поэтому доработку проекта я оставлю на "лучшие времена". Спасибо.
# </div>
